# %%
# !pip3 install requests

# %%
import requests
from requests.auth import HTTPBasicAuth

# %%
import pandas as pd

# %%
#dados https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao
# https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao
# https://opendatasus.saude.gov.br/dataset/8e0c325d-2586-4b11-8925-4ba51acd6e6d/resource/84707ab9-8497-4f2f-8a0d-b873489a63bf/download/manual_api_vacina_covid-19.pdf

# %%
url = 'https://imunizacao-es.saude.gov.br/_search'

# %%
response = requests.get(url, auth = HTTPBasicAuth ('imunizacao_public', 'qlto5t&7r_@+#Tlstigi'))

# %%
response.json()
# Out:
# {'took': 9,
#  'timed_out': False,
#  '_shards': {'total': 30, 'successful': 30, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'desc-imunizacao-v5',
#     '_type': '_doc',
#     '_id': 'ce2b0afd-2f84-483c-a9e5-6dd363470dc8-i0b0',
#     '_score': 1.0,
#     '_source': {'sistema_origem': 'VACIVIDA',
#      'paciente_endereco_coPais': '10',
#      'vacina_codigo': '85',
#      'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#      'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#      'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#      'paciente_enumSexoBiologico': 'F',
#      'paciente_endereco_uf': 'SP',
#      'data_importacao_rnds': '2021-07-12T03:00:00.000Z',
#      'paciente_racaCor_valor': 'SEM INFORMACAO',
#      'vacina_categoria_codigo': '2',
#      'estabelecimento_valor': '3762831',
# ...

# %%
vacinacao = response.json()

# %%
vacinacao ['hits']['hits']
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'ce2b0afd-2f84-483c-a9e5-6dd363470dc8-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'paciente_endereco_coPais': '10',
#    'vacina_codigo': '85',
#    'vacina_fabricante_nome': 'ASTRAZENECA/FIOCRUZ',
#    'vacina_nome': 'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_uf': 'SP',
#    'data_importacao_rnds': '2021-07-12T03:00:00.000Z',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'vacina_categoria_codigo': '2',
#    'estabelecimento_valor': '3762831',
#    'paciente_id': '1d3c0bb60087e88a95667ceacdc9fb34fb76dd58f9b2361886a22c90252ccb9c',
#    'vacina_lote': '216VCD186Z',
#    'data_importacao_datalake': '2022-08-25T18:17:26.000Z',
#    'estabelecimento_uf': 'SP',
#    '@timestamp': '2022-08-25T21:19:36.014Z',
# ...

# %%
pd.json_normalize(vacinacao['hits']['hits'])
# Out:
#                _index _type                                        _id  \
# 0  desc-imunizacao-v5  _doc  ce2b0afd-2f84-483c-a9e5-6dd363470dc8-i0b0
# 1  desc-imunizacao-v5  _doc  cf28ea89-8535-4bbd-a81f-bc20f4fbfec3-i0b0
# 2  desc-imunizacao-v5  _doc  52061339-65ff-4e0b-9601-11ef2d73a757-i0b0
# 3  desc-imunizacao-v5  _doc  59ccdc33-be27-4800-949d-3041e0d96df6-i0b0
# 4  desc-imunizacao-v5  _doc  0b3fcdad-4906-4b93-b7b1-3c17cb46c17c-i0b0
# 5  desc-imunizacao-v5  _doc  e7788fdf-74c3-4b69-8bfd-d2f4486651f8-i0b0
# 6  desc-imunizacao-v5  _doc  0671fdfe-5ebe-429f-8c1e-1ede1d58d429-i0b0
# 7  desc-imunizacao-v5  _doc  369a1d82-08ea-4fc6-9ac7-73a15964ac29-i0b0
# 8  desc-imunizacao-v5  _doc  59e90a06-3a5a-4b3b-85e1-743b199012b0-i0b0
# 9  desc-imunizacao-v5  _doc  f5f96459-a5a4-4e1c-9953-79530d9477b2-i0b0
#
#    _score _source.sistema_origem _source.paciente_endereco_coPais  \
# 0     1.0               VACIVIDA                               10
# ...

# %%
vacinacao_2 = pd.json_normalize(vacinacao['hits']['hits'])

# %%
vacinacao_2
# Out:
#                _index _type                                        _id  \
# 0  desc-imunizacao-v5  _doc  ce2b0afd-2f84-483c-a9e5-6dd363470dc8-i0b0
# 1  desc-imunizacao-v5  _doc  cf28ea89-8535-4bbd-a81f-bc20f4fbfec3-i0b0
# 2  desc-imunizacao-v5  _doc  52061339-65ff-4e0b-9601-11ef2d73a757-i0b0
# 3  desc-imunizacao-v5  _doc  59ccdc33-be27-4800-949d-3041e0d96df6-i0b0
# 4  desc-imunizacao-v5  _doc  0b3fcdad-4906-4b93-b7b1-3c17cb46c17c-i0b0
# 5  desc-imunizacao-v5  _doc  e7788fdf-74c3-4b69-8bfd-d2f4486651f8-i0b0
# 6  desc-imunizacao-v5  _doc  0671fdfe-5ebe-429f-8c1e-1ede1d58d429-i0b0
# 7  desc-imunizacao-v5  _doc  369a1d82-08ea-4fc6-9ac7-73a15964ac29-i0b0
# 8  desc-imunizacao-v5  _doc  59e90a06-3a5a-4b3b-85e1-743b199012b0-i0b0
# 9  desc-imunizacao-v5  _doc  f5f96459-a5a4-4e1c-9953-79530d9477b2-i0b0
#
#    _score _source.sistema_origem _source.paciente_endereco_coPais  \
# 0     1.0               VACIVIDA                               10
# ...

# %%
vacinacao_2.head()
# Out:
#                _index _type                                        _id  \
# 0  desc-imunizacao-v5  _doc  ce2b0afd-2f84-483c-a9e5-6dd363470dc8-i0b0
# 1  desc-imunizacao-v5  _doc  cf28ea89-8535-4bbd-a81f-bc20f4fbfec3-i0b0
# 2  desc-imunizacao-v5  _doc  52061339-65ff-4e0b-9601-11ef2d73a757-i0b0
# 3  desc-imunizacao-v5  _doc  59ccdc33-be27-4800-949d-3041e0d96df6-i0b0
# 4  desc-imunizacao-v5  _doc  0b3fcdad-4906-4b93-b7b1-3c17cb46c17c-i0b0
#
#    _score _source.sistema_origem _source.paciente_endereco_coPais  \
# 0     1.0               VACIVIDA                               10
# 1     1.0               Novo PNI                               10
# 2     1.0               VACIVIDA                               10
# 3     1.0               VACIVIDA                               10
# 4     1.0               Novo PNI                               10
#
#   _source.vacina_codigo _source.vacina_fabricante_nome  \
# 0                    85            ASTRAZENECA/FIOCRUZ
# ...

# %%
import os
from dotenv import load_dotenv

# %%
import sqlalchemy as sa

# %%
load_dotenv('credentials/vacinacao.env')
# Out:
# True

# %%
load_dotenv('credentials/vacinacao.env')
url_banco = "localhost"
nome_db = "vacinacao"
conn_str = f"mysql+pymysql://root:970407@{url_banco}/{nome_db}"
engine = sa.create_engine(conn_str)

# %%
print(conn_str)
# Out:
# mysql+pymysql://None:None@localhost/vacinacao

# %%
print(engine)
# Out:
# Engine(mysql+pymysql://None:***@localhost/vacinacao)

# %%
vacinacao_2.to_sql('vacinacao', engine, index = False, if_exists = 'replace') #vídeo API Wrappers 1:09
